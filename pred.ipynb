# %%
# !pip install Pycaret

# %%
from pycaret.utils import version
version()
# Out:
# '3.0.0'

# %%
from pycaret.datasets import get_data
dataset = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
#parameter setting for regression model
from pycaret.regression import *
s= setup(data=data, target = "charges", train_size=0.7)
# Out:
# <style type="text/css">
# #T_8e347_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8e347" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e347_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8e347_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e347_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e347_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8e347_row0_col1" class="data row0 col1" >5093</td>
#     </tr>
#     <tr>
#       <th id="T_8e347_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e347_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8e347_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_8e347_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
data = get_data('insurance')
#size of the dataset
print("Dataset size:", data.shape)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# Dataset size: (1338, 7)

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
data = get_data('insurance')

# Create a scatter plot of 'age' vs 'charges'
plt.scatter(data['age'], data['charges'])
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Age vs Charges')
plt.show()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#run and compare the models perfomance
cm = compare_models()
# Out:
# <style type="text/css">
# #T_29e67 th {
#   text-align: left;
# }
# ...

# %%
#3lines code for model comparsion for insurance dataset
from pycaret.datasets import get_data
from pycaret.regression import *

dataset = get_data('insurance')
s = setup(data=dataset,target='charges')
cm = compare_models
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_22ecf_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22ecf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22ecf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_22ecf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22ecf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22ecf_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %%
model= create_model('gbr')
#saving the model
sm = save_model(model, 'model_save_GRB')
# Out:
# <style type="text/css">
# #T_2b619_row10_col0, #T_2b619_row10_col1, #T_2b619_row10_col2, #T_2b619_row10_col3, #T_2b619_row10_col4, #T_2b619_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2b619" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b619_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2b619_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2b619_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2b619_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2b619_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2b619_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
#load the model and make predicition
#load
model = load_model('/content/model_save_GRB')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
#make prediction
import pandas as pd
data = {'age' : 40,
        'sex' : 1,
        'bmi' : 40.30,
        'children' : 4,
        'smoker' : 1,
        'region' : 2}
#index = [1]
df = pd.DataFrame(data,index=[0])
df
# Out:
#    age  sex   bmi  children  smoker  region
# 0  100    1  40.3         4       1       2

# %%
pred = predict_model(model,df)
pred
# Out:
#    age  sex        bmi  children  smoker  region  prediction_label
# 0  100    1  40.299999         4       1       2      16728.642454

# %%
#make prediction
import pandas as pd
data = {'age' : 20,
        'sex' : 0,
        'bmi' : 25.30,
        'children' : 1,
        'smoker' : 0,
        'region' : 4}
#index = [1]
df = pd.DataFrame(data,index=[0])
df
# Out:
#    age  sex   bmi  children  smoker  region
# 0   20    0  25.3         1       0       4

# %%
pred = predict_model(model,df)
pred
# Out:
#    age  sex        bmi  children  smoker  region  prediction_label
# 0   20    0  25.299999         1       0       4       5042.321223

# %%
#make prediction
import pandas as pd
data = {'age' : 33,
        'sex' : 1,
        'bmi' : 22.25,
        'children' : 0,
        'smoker' : 1,
        'region' : 5}
#index = [1]
df = pd.DataFrame(data,index=[0])
df
# Out:
#    age  sex    bmi  children  smoker  region
# 0   33    1  22.25         0       1       5

# %%
pred = predict_model(model,df)
pred
# Out:
#    age  sex    bmi  children  smoker  region  prediction_label
# 0   33    1  22.25         0       1       5       4654.436347
